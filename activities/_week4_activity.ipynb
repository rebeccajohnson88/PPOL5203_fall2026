# %% [markdown]
# # Week 4 Activities: Python Iteration, Comprehension, and Generators

# %% [markdown]
# ## Activity 1: For loops

# %%
## start with these objects
list_exercise = ["Giants", "Commanders", "Eagles", "Jets"] 
sports_dict = {'Team': ["Giants", "Commanders", "Eagles", "Jets"],
              'City': ["Dallas", "DC", "Philadelphia", "NYC"],
              'Week1': [1, 0, 1, 1]}

# %% [markdown]
# A. Using a `for` statement, iterate over each element in `list_exercise` and print a lowercase version of the element. Print the `list_exercise` list after the loop and check to make sure the elements have not been modified

# %%
## your code here
for element in list_exercise:
    print(element.lower())
# Out:
# giants
# commanders
# eagles
# jets

# %%
list_exercise
# Out:
# ['Giants', 'Commanders', 'Eagles', 'Jets']

# %% [markdown]
# B. Using a `for` statement, iterate over each element in `list_exercise` and print the following statement: "The team is called the [insert name of team]"
#
# **Note**: to create the combined string, you can use quote the `+` operator - see here: https://www.w3schools.com/Python/python_strings_concatenate.asp

# %%
## your code here
for element in list_exercise:
    print("The team is called the " + element)
# Out:
# The team is called the Giants
# The team is called the Commanders
# The team is called the Eagles
# The team is called the Jets

# %% [markdown]
# C. Run the following code to iterate over the values in `sports_dict` to print the following statement: "The [Insert name of team] play in [Insert city of team]"
#
# **Note**: here, we're iterating using the positions of the elements in each of the dictionary's lists. Later, we'll learn a more efficient way to do this where we don't need to separate out the lists

# %%
teams = sports_dict['Team']
cities = sports_dict['City']

# %%
for i in range(len(teams)):
    print("The " + teams[i] + " play in " + cities[i])
# Out:
# The Giants play in Dallas
# The Commanders play in DC
# The Eagles play in Philadelphia
# The Jets play in NYC

# %% [markdown]
# D. Use an `if` `else` statement within a `for` loop to iterate over the list in the `Week1` key of `sports_dict`. If the week 1 results takes the value of 1, print "[Insert team name] won!" Otherwise, print "[Insert team name] lost :("
#
# **Note**: because we only have two possible outcomes, we can skip the `elif` part from the slides

# %%
## your code here
results = sports_dict['Week1']
for i in range(len(results)):
    if results[i] == 1:
        print(teams[i] + " won!")
    elif results[i] == 0:
        print(teams[i] + " lost :(")
    else:
        print("Check your results list")
# Out:
# Giants won!
# Commanders lost :(
# Eagles won!
# Jets won!

# %% [markdown]
# ## Activity 2: while loop

# %% [markdown]
# A. Initialize a value of `x = 3`. Use the `x-=1` syntax to remove 1 from x with each iteration of the while loop. Stop the loop before x falls below 0

# %%
## your code here 
x = 3
while x >= 0:
    print(x)
    x -=1
# Out:
# 3
# 2
# 1
# 0

# %% [markdown]
# ## Activity 3: user-defined functions

# %% [markdown]
# A. Define a function called `go_team` that takes in a single argument called `team_name`, a string for team, and returns the phrase ("Go [insert name of team]!")
#
# Execute the function using string "Commanders"

# %%
## your code here
def go_team(team_name):
    phrase = "Go " + team_name + "!"
    return phrase

go_team(team_name = "Commanders")
# Out:
# 'Go Commanders!'

# %% [markdown]
# B. Define a function called `go_team_city` that takes in two arguments:
# - `team_name`: string for name of team
# - `team_city`: string for city of team
#
# And returns the phrase: "Go [insert name of team] from [insert name of city]!"
#
# Execute the function using Commanders as the team name and DC as the city

# %%
## your code here
def go_team_city(team_name, team_city):
    phrase =  "Go " + team_name + " from " + team_city + "!"
    return phrase

commanders_cheer = go_team_city(team_name = "Commanders", team_city = "DC")

# %%
commanders_cheer
# Out:
# 'Go Commanders from DC!'

# %%
def go_team_city_noreturn(team_name, team_city):
    print("Go " + team_name + " from " + team_city + "!")
    return None

# %%
go_team_city_noreturn(team_name = "Commanders", team_city = "DC")
# Out:
# Go Commanders from DC!

# %%
test = go_team_city_noreturn(team_name = "Commanders", team_city = "DC")
# Out:
# Go Commanders from DC!

# %%
test

# %% [markdown]
# C. Execute that same function but instead of feeding team_name and team_city as named arguments, feed them as positional arguments

# %%
## your code here
go_team_city("Commanders", "DC")
# Out:
# 'Go Commanders from DC!'

# %% [markdown]
# D. Create a `lambda` function version of `go_team` and use map to apply it to the list of team names (sports_dict['Team'])

# %%
sports_dict['Team']
# Out:
# ['Giants', 'Commanders', 'Eagles', 'Jets']

# %%
## your code here
team_cheers = list(map(lambda x: "Go " + x + "!", sports_dict['Team']))
team_cheers
# Out:
# ['Go Giants!', 'Go Commanders!', 'Go Eagles!', 'Go Jets!']

# %% [markdown]
# ## Activity 4: List comprehension

# %% [markdown]
# A. Using list comprehension, iterate over the list of teams (`sports_dict['Team']`) and print
# "The team is called the [insert name of team]"

# %%
[team for team in sports_dict['Team']]
# Out:
# ['Giants', 'Commanders', 'Eagles', 'Jets']

# %%
## your code here
["The team is called " + team for team in sports_dict['Team']]
# Out:
# ['The team is called Giants',
#  'The team is called Commanders',
#  'The team is called Eagles',
#  'The team is called Jets']

# %% [markdown]
# B. Using list comprehension, iterate over the list of teams (sports_dict['Team']) and, if the length of the team name is 6 characters or fewer,
# print "The team is called the [insert name of team]"; otherwise, skip

# %%
## your code here 
["The team is called " + team for team in sports_dict['Team']
if len(team) <= 6]
# Out:
# ['The team is called Giants',
#  'The team is called Eagles',
#  'The team is called Jets']

# %% [markdown]
# ## Activity 5: Generators

# %% [markdown]
# A. Use the `zip` function to zip together the lists of teams (`sports_dict['Team']`) and results (`sports_dict['Week1']`). Store this zip object as team_w_results

# %%
## your code here
team_w_results = zip(sports_dict['Team'], sports_dict['Week1'])

# %% [markdown]
# B. Using a for loop, iterate over the zipped object and print "[Insert team name]  won!" if the results is equal to 1; else print "[Insert team name] lost :("
#
# **Note**: this is same task as Activity 1, Exercise D but you should be able to use simpler syntax that avoids the range generator

# %%
## your code here
for team, result in team_w_results:
    if result == 1:
        print(team + " won!")
    elif result == 0:
        print(team + " lost :(")
# Out:
# Giants won!
# Commanders lost :(
# Eagles won!
# Jets won!

# %% [markdown]
# C. Complete the task in part B but using list comprehension instead of a for loop. Note, you need to regenerate the team_w_results iterator which you can either do before the list comprehension or inside the list comprehension

# %%
## your code here 
[team + " won!" if result == 1
 else team + " lost :("
 for team, result 
 in zip(sports_dict['Team'], sports_dict['Week1'])]
# Out:
# ['Giants won!', 'Commanders lost :(', 'Eagles won!', 'Jets won!']

# %%
[team 
 for team, result 
 in zip(sports_dict['Team'], sports_dict['Week1'])
if result == 1]
# Out:
# ['Giants', 'Eagles', 'Jets']
