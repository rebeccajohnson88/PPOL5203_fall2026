# %% [markdown]
# # Week 3 Activities: Intro to Python

# %% [markdown]
# ## Activity 1: Lists
#
# - Check all the methods of a list by running 'dir()' on a list object.
# - See [here](https://www.w3schools.com/python/python_ref_list.asp) for list methods

# %%
list_exercise = ["Giants", "Commanders", "Eagles", "Jets"]

# %% [markdown]
# A.   Add "Cowboys" to `list_exercise` (the position of the element doesn't matter) and print the list

# %%
## your code here

# %% [markdown]
# B. Remove "Jets" from the list

# %%
## your code here

# %% [markdown]
# C.  Find and print the index of the occurrence of the name "Commanders"

# %%
## your code here

# %% [markdown]
# D. Count the number of times None appears in the list.

# %%
## your code here

# %% [markdown]
# E. Create a copy of `list_exercise` called `list_copy`. Sort the names in alphabetical order for `list_copy`. Print both `list_exercise` and `list_copy` to make sure that the sort only applied to `list_copy`

# %%
## your code here

# %% [markdown]
# F. Add the string "Patriots" to `list_copy` and ensure that `list_exercise` remains unchanged.

# %%
## your code here

# %% [markdown]
# ## Activity 2: Dictionaries
#
# - Let's do a similar exercise with Dictionaries
# - See [here](https://www.w3schools.com/python/python_ref_dictionary.asp) for dictionary methods:

# %%
dict_exercise = {"Giants": "NYC",
                  "Commanders":"Washington DC", 
                  "Eagles":"Philadelphia"}

# %% [markdown]
# A. Look up the keys in the dictionary, and store them in a list object called `keys`. Print `keys` and check its type to confirm it's a list

# %%
## your code here

# %% [markdown]
# B. Add the team Dallas Cowboys to the dictionary, where the key is Cowboys and the value is Dallas

# %%
## your code here

# %% [markdown]
# C.  Store the key-value pair for the Washington Commanders as a separate dictionary called `dict_new` and remove that key-value pair from `dict_exercise`

# %%
## your code here

# %% [markdown]
# ## Activity 3: strings
#
# - The previous activities contained strings as elements of the lists/dictionaries
# - Let's now practice some string methods
# - See the string below from recent McCourt news
# - See [here](https://www.w3schools.com/python/python_ref_string.asp) for string methods

# %%
mcc = """
mcc = "There’s been a flurry of activity around the building,
and I’m here for it, as my kids would say.  We are exceptionally 
proud of, and grateful for, our beautiful physical space here at
125 E Street and last week, we became even prouder."
"""

# %% [markdown]
# A. Determine if the word "Washington" is present in the string. Determine if the word "week" is in the string.

# %%
## your code here

# %% [markdown]
# B. Count how many times the word "grateful" appears

# %%
## your code here

# %% [markdown]
# C. Convert the entire string to upper case

# %%
## your code here

# %% [markdown]
# D. Replace the phrase "We" with "I" throughout the string

# %%
## your code here

# %% [markdown]
# E. Run the below code to strip any punctuation (like commas, exclamation marks, etc.) from the string - next week, we'll be covering `for

# %%
# Define a string containing some punctuation marks.
punctuation = ",'.!"

# Iterate over: we will see this later. 
for char in punctuation:
    mcc = mcc.replace(char, "")
    
print(mcc)
# Out:
# mcc = "There’s been a flurry of activity around the building
# and I’m here for it as my kids would say  We are exceptionally
# proud of and grateful for our beautiful physical space here at
# 125 E Street and last week we became even prouder"

# %% [markdown]
# ## Activity 4: Combining lists and dictionary
#
# Now, we will practice combining lists and dictionary by using a dictionary where the elements are lists

# %% [markdown]
# A. Begin by checking the type of the sports_dict object

# %%
sports_dict = {'Team': ["Giants", "Commanders", "Eagles", "Jets"],
              'City': ["Dallas", "DC", "Philadelphia", "NYC"]}

## your code here

# %% [markdown]
# B. Subset the dictionary to the `Team` key and check the type

# %%
## your code here

# %% [markdown]
# C. Add the Patriots as the last elements of the 'Team' list and Boston as the last element of the `City` list within the dictionary

# %%
## your code here

# %%
## your code here

# %% [markdown]
# D. Remove the Jets and NYC from their respective lists

# %%
## your code here

# %% [markdown]
# E. Print the length of each of the lists in the dictionary

# %%
## your code here
