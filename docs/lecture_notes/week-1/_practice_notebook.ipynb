# %%
# Check that Python is installed 
# The ! point allows us to run a 
# command line argument from a notebook
# !python --version
# Out:
# Python 3.9.13

# %%
# Check that git is installed
# !where git
# Out:
# /usr/bin/git

# %%
# Print your current working directory
import os
os.getcwd()
# Out:
# '/Users/rj545/Dropbox/PPOL5203_fall2026/lecture_notes/week-1'
